# %%
import tensorflow as tf
import preprocessing
import numpy as np
import math

# %%
url = 'http://mattmahoney.net/dc/'
filename = preprocessing.maybe_download(url,'text8.zip', 31344016)
words = preprocessing.read_data(filename)
print('Data size', len(words))
# Out:
# ('Found and verified', 'text8.zip')
# ('Data size', 17005207)

# %%
vocabulary_size = 50000
data, count, dictionary, reverse_dictionary = preprocessing.build_dataset(vocabulary_size,words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# ('Most common words (+UNK)', [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)])
# ('Sample data', [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156], ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against'])

# %%
batch, labels = preprocessing.generate_batch(data, data_index,batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# (3084, 'originated', '->', 12, 'as')
# (3084, 'originated', '->', 5239, 'anarchism')
# (12, 'as', '->', 3084, 'originated')
# (12, 'as', '->', 6, 'a')
# (6, 'a', '->', 12, 'as')
# (6, 'a', '->', 195, 'term')
# (195, 'term', '->', 6, 'a')
# (195, 'term', '->', 2, 'of')

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

# %%
graph = tf.Graph()
with graph.as_default():
    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
    loss = tf.reduce_mean(
        tf.nn.nce_loss(weights=nce_weights,
                       biases=nce_biases,
                       labels=train_labels,
                       inputs=embed,
                       num_sampled=num_sampled,
                       num_classes=vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Add variable initializer.
    init = tf.global_variables_initializer()

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = preprocessing.generate_batch(data,data_index,batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val
        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# ('Average loss at step ', 0, ': ', 271.1060791015625)
# Nearest to was: hassan, creating, breakthroughs, subjunctive, ballista, mackintosh, yusupov, htm,
# Nearest to who: timbres, populations, tsushima, enjoy, activision, trailers, ward, presley,
# Nearest to four: ensued, macedonia, courted, scantily, wysiwyg, lovelock, unambiguously, stamped,
# Nearest to history: lemming, pilgrims, libel, byrnes, frontal, comfortably, refugee, trait,
# Nearest to such: romanum, osamu, yearbook, vanderbilt, roundly, travolta, kashima, uranium,
# Nearest to this: ankh, bobby, dizzy, silicon, bidder, boitano, curly, nevado,
# Nearest to eight: whitehead, pythagorean, meteor, splitting, antagonistic, catiline, eradicate, montessori,
# Nearest to about: contexts, debilitating, protocol, creeping, inclusive, chant, middle, mand,
# Nearest to UNK: kernel, shrews, columbus, hagiography, catastrophes, tsushima, emory, nahum,
# Nearest to these: tropes, broz, designed, schottenheimer, archeological, surfacing, townes, czes,
# Nearest to years: tubas, televised, transliterated, adequacy, colitis, residue, stained, mathematically,
# Nearest to use: harbors, outburst, bendix, staking, declined, hexagonal, contested, leche,
# Nearest to the: omni, sum, poisons, seeing, mainland, bite, mgm, approx,
# Nearest to united: labouring, supposedly, agronomy, forgiving, dancing, reconstructionism, presidential, quimby,
# Nearest to that: mayr, aft, vegans, preeminent, veil, rower, vodafone, needless,
# Nearest to often: crystallization, lya, guiding, jacobian, sirhan, assumes, jscript, advisers,
# ('Average loss at step ', 2000, ': ', 96.379850055694575)
# ('Average loss at step ', 4000, ': ', 40.217240690916775)
# ('Average loss at step ', 6000, ': ', 23.065034366130828)
# ('Average loss at step ', 8000, ': ', 14.481553724735976)
# ('Average loss at step ', 10000, ': ', 10.056174887627364)
# Nearest to was: hassan, creating, breakthroughs, subjunctive, ballista, mackintosh, yusupov, htm,
# Nearest to who: timbres, populations, tsushima, enjoy, activision, trailers, ward, presley,
# Nearest to four: ensued, macedonia, courted, scantily, wysiwyg, lovelock, unambiguously, stamped,
# Nearest to history: lemming, pilgrims, libel, byrnes, frontal, comfortably, refugee, trait,
# Nearest to such: romanum, osamu, yearbook, vanderbilt, roundly, travolta, kashima, uranium,
# Nearest to this: ankh, bobby, dizzy, silicon, bidder, boitano, curly, nevado,
# Nearest to eight: whitehead, pythagorean, meteor, splitting, antagonistic, catiline, eradicate, montessori,
# Nearest to about: contexts, debilitating, protocol, creeping, inclusive, chant, middle, mand,
# Nearest to UNK: used, has, of, class, self, it, any, label,
# Nearest to these: tropes, broz, designed, schottenheimer, archeological, surfacing, townes, czes,
# Nearest to years: tubas, televised, transliterated, adequacy, colitis, residue, stained, mathematically,
# Nearest to use: harbors, outburst, bendix, staking, declined, hexagonal, contested, leche,
# Nearest to the: used, of, term, class, also, a, against, as,
# Nearest to united: labouring, supposedly, agronomy, forgiving, dancing, reconstructionism, presidential, quimby,
# Nearest to that: also, used, by, has, french, any, as, the,
# Nearest to often: crystallization, lya, guiding, jacobian, sirhan, assumes, jscript, advisers,
# ('Average loss at step ', 12000, ': ', 6.8488501288592811)
# ('Average loss at step ', 14000, ': ', 4.5641103303432464)
# ('Average loss at step ', 16000, ': ', 3.4400915063917639)
# ('Average loss at step ', 18000, ': ', 2.8762651031911375)
# ('Average loss at step ', 20000, ': ', 2.0825833165943624)
# Nearest to was: hassan, creating, breakthroughs, subjunctive, ballista, mackintosh, yusupov, htm,
# Nearest to who: timbres, populations, tsushima, enjoy, activision, trailers, ward, presley,
# Nearest to four: ensued, macedonia, courted, scantily, wysiwyg, lovelock, unambiguously, stamped,
# Nearest to history: lemming, pilgrims, libel, byrnes, frontal, comfortably, refugee, trait,
# Nearest to such: romanum, osamu, yearbook, vanderbilt, roundly, travolta, kashima, uranium,
# Nearest to this: ankh, bobby, dizzy, silicon, bidder, boitano, curly, nevado,
# Nearest to eight: whitehead, pythagorean, meteor, splitting, antagonistic, catiline, eradicate, montessori,
# Nearest to about: contexts, debilitating, protocol, creeping, inclusive, chant, middle, mand,
# Nearest to UNK: has, class, used, any, self, taken, it, label,
# Nearest to these: tropes, broz, designed, schottenheimer, archeological, surfacing, townes, czes,
# Nearest to years: tubas, televised, transliterated, adequacy, colitis, residue, stained, mathematically,
# Nearest to use: harbors, outburst, bendix, staking, declined, hexagonal, contested, leche,
# Nearest to the: used, of, a, also, term, as, working, act,
# Nearest to united: labouring, supposedly, agronomy, forgiving, dancing, reconstructionism, presidential, quimby,
# Nearest to that: also, used, by, as, the, french, has, any,
# Nearest to often: crystallization, lya, guiding, jacobian, sirhan, assumes, jscript, advisers,
# ('Average loss at step ', 22000, ': ', 1.6911521573364734)
# ('Average loss at step ', 24000, ': ', 1.4929761715829373)
# ('Average loss at step ', 26000, ': ', 1.3873436692357064)
# ('Average loss at step ', 28000, ': ', 1.2020251638591291)
# ('Average loss at step ', 30000, ': ', 1.1836533473134041)
# Nearest to was: hassan, creating, breakthroughs, subjunctive, ballista, mackintosh, yusupov, htm,
# Nearest to who: timbres, populations, tsushima, enjoy, activision, trailers, ward, presley,
# Nearest to four: ensued, macedonia, courted, scantily, wysiwyg, lovelock, unambiguously, stamped,
# Nearest to history: lemming, pilgrims, libel, byrnes, frontal, comfortably, refugee, trait,
# Nearest to such: romanum, osamu, yearbook, vanderbilt, roundly, travolta, kashima, uranium,
# Nearest to this: ankh, bobby, dizzy, silicon, bidder, boitano, curly, nevado,
# Nearest to eight: whitehead, pythagorean, meteor, splitting, antagonistic, catiline, eradicate, montessori,
# Nearest to about: contexts, debilitating, protocol, creeping, inclusive, chant, middle, mand,
# Nearest to UNK: has, class, the, used, any, self, taken, to,
# Nearest to these: tropes, broz, designed, schottenheimer, archeological, surfacing, townes, czes,
# Nearest to years: tubas, televised, transliterated, adequacy, colitis, residue, stained, mathematically,
# Nearest to use: harbors, outburst, bendix, staking, declined, hexagonal, contested, leche,
# Nearest to the: used, term, as, of, a, to, also, has,
# Nearest to united: labouring, supposedly, agronomy, forgiving, dancing, reconstructionism, presidential, quimby,
# Nearest to that: also, used, as, the, by, french, has, a,
# Nearest to often: crystallization, lya, guiding, jacobian, sirhan, assumes, jscript, advisers,
# ('Average loss at step ', 32000, ': ', 1.127650441378355)
# ('Average loss at step ', 34000, ': ', 1.0709389137327672)
# ('Average loss at step ', 36000, ': ', 1.0015761176645757)
# ('Average loss at step ', 38000, ': ', 1.0095734983086586)
# ('Average loss at step ', 40000, ': ', 0.99610469901561738)
# Nearest to was: hassan, creating, breakthroughs, subjunctive, ballista, mackintosh, yusupov, htm,
# Nearest to who: timbres, populations, tsushima, enjoy, activision, trailers, ward, presley,
# Nearest to four: ensued, macedonia, courted, scantily, wysiwyg, lovelock, unambiguously, stamped,
# Nearest to history: lemming, pilgrims, libel, byrnes, frontal, comfortably, refugee, trait,
# Nearest to such: romanum, osamu, yearbook, vanderbilt, roundly, travolta, kashima, uranium,
# Nearest to this: ankh, bobby, dizzy, silicon, bidder, boitano, curly, nevado,
# Nearest to eight: whitehead, pythagorean, meteor, splitting, antagonistic, catiline, eradicate, montessori,
# Nearest to about: contexts, debilitating, protocol, creeping, inclusive, chant, middle, mand,
# Nearest to UNK: the, class, has, used, self, any, taken, to,
# Nearest to these: tropes, broz, designed, schottenheimer, archeological, surfacing, townes, czes,
# Nearest to years: tubas, televised, transliterated, adequacy, colitis, residue, stained, mathematically,
# Nearest to use: harbors, outburst, bendix, staking, declined, hexagonal, contested, leche,
# Nearest to the: of, used, a, to, term, as, also, class,
# Nearest to united: labouring, supposedly, agronomy, forgiving, dancing, reconstructionism, presidential, quimby,
# Nearest to that: also, as, used, the, by, french, has, a,
# Nearest to often: crystallization, lya, guiding, jacobian, sirhan, assumes, jscript, advisers,
# ('Average loss at step ', 42000, ': ', 0.99545777451992035)
# ('Average loss at step ', 44000, ': ', 0.95962407931685445)
# ('Average loss at step ', 46000, ': ', 0.96053954136371611)
# ('Average loss at step ', 48000, ': ', 0.94993579950928686)
# ('Average loss at step ', 50000, ': ', 0.96120248153805732)
# Nearest to was: hassan, creating, breakthroughs, subjunctive, ballista, mackintosh, yusupov, htm,
# Nearest to who: timbres, populations, tsushima, enjoy, activision, trailers, ward, presley,
# Nearest to four: ensued, macedonia, courted, scantily, wysiwyg, lovelock, unambiguously, stamped,
# Nearest to history: lemming, pilgrims, libel, byrnes, frontal, comfortably, refugee, trait,
# Nearest to such: romanum, osamu, yearbook, vanderbilt, roundly, travolta, kashima, uranium,
# Nearest to this: ankh, bobby, dizzy, silicon, bidder, boitano, curly, nevado,
# Nearest to eight: whitehead, pythagorean, meteor, splitting, antagonistic, catiline, eradicate, montessori,
# Nearest to about: contexts, debilitating, protocol, creeping, inclusive, chant, middle, mand,
# Nearest to UNK: the, class, has, used, self, any, taken, to,
# Nearest to these: tropes, broz, designed, schottenheimer, archeological, surfacing, townes, czes,
# Nearest to years: tubas, televised, transliterated, adequacy, colitis, residue, stained, mathematically,
# Nearest to use: harbors, outburst, bendix, staking, declined, hexagonal, contested, leche,
# Nearest to the: of, used, a, term, to, as, class, also,
# Nearest to united: labouring, supposedly, agronomy, forgiving, dancing, reconstructionism, presidential, quimby,
# Nearest to that: also, as, used, by, the, french, to, has,
# Nearest to often: crystallization, lya, guiding, jacobian, sirhan, assumes, jscript, advisers,
# ('Average loss at step ', 52000, ': ', 0.95441819828748709)
# ('Average loss at step ', 54000, ': ', 0.93522757366299625)
# ('Average loss at step ', 56000, ': ', 0.93972700339555737)
# ('Average loss at step ', 58000, ': ', 0.94128561699390412)
# ('Average loss at step ', 60000, ': ', 0.93849929443001745)
# Nearest to was: hassan, creating, breakthroughs, subjunctive, ballista, mackintosh, yusupov, htm,
# Nearest to who: timbres, populations, tsushima, enjoy, activision, trailers, ward, presley,
# Nearest to four: ensued, macedonia, courted, scantily, wysiwyg, lovelock, unambiguously, stamped,
# Nearest to history: lemming, pilgrims, libel, byrnes, frontal, comfortably, refugee, trait,
# Nearest to such: romanum, osamu, yearbook, vanderbilt, roundly, travolta, kashima, uranium,
# Nearest to this: ankh, bobby, dizzy, silicon, bidder, boitano, curly, nevado,
# Nearest to eight: whitehead, pythagorean, meteor, splitting, antagonistic, catiline, eradicate, montessori,
# Nearest to about: contexts, debilitating, protocol, creeping, inclusive, chant, middle, mand,
# Nearest to UNK: the, used, class, has, to, self, any, taken,
# Nearest to these: tropes, broz, designed, schottenheimer, archeological, surfacing, townes, czes,
# Nearest to years: tubas, televised, transliterated, adequacy, colitis, residue, stained, mathematically,
# Nearest to use: harbors, outburst, bendix, staking, declined, hexagonal, contested, leche,
# Nearest to the: a, used, of, to, term, as, class, society,
# Nearest to united: labouring, supposedly, agronomy, forgiving, dancing, reconstructionism, presidential, quimby,
# Nearest to that: also, as, used, to, by, the, french, a,
# Nearest to often: crystallization, lya, guiding, jacobian, sirhan, assumes, jscript, advisers,
# ('Average loss at step ', 62000, ': ', 0.93720952382683753)
# ('Average loss at step ', 64000, ': ', 0.93959533393383021)
# ('Average loss at step ', 66000, ': ', 0.93519062432646749)
# ('Average loss at step ', 68000, ': ', 0.93323426279425625)
# ('Average loss at step ', 70000, ': ', 0.9448607483208179)
# Nearest to was: hassan, creating, breakthroughs, subjunctive, ballista, mackintosh, yusupov, htm,
# Nearest to who: timbres, populations, tsushima, enjoy, activision, trailers, ward, presley,
# Nearest to four: ensued, macedonia, courted, scantily, wysiwyg, lovelock, unambiguously, stamped,
# Nearest to history: lemming, pilgrims, libel, byrnes, frontal, comfortably, refugee, trait,
# Nearest to such: romanum, osamu, yearbook, vanderbilt, roundly, travolta, kashima, uranium,
# Nearest to this: ankh, bobby, dizzy, silicon, bidder, boitano, curly, nevado,
# Nearest to eight: whitehead, pythagorean, meteor, splitting, antagonistic, catiline, eradicate, montessori,
# Nearest to about: contexts, debilitating, protocol, creeping, inclusive, chant, middle, mand,
# Nearest to UNK: the, used, class, has, self, any, taken, a,
# Nearest to these: tropes, broz, designed, schottenheimer, archeological, surfacing, townes, czes,
# Nearest to years: tubas, televised, transliterated, adequacy, colitis, residue, stained, mathematically,
# Nearest to use: harbors, outburst, bendix, staking, declined, hexagonal, contested, leche,
# Nearest to the: of, used, a, to, term, as, class, society,
# Nearest to united: labouring, supposedly, agronomy, forgiving, dancing, reconstructionism, presidential, quimby,
# Nearest to that: also, used, as, the, to, by, french, a,
# Nearest to often: crystallization, lya, guiding, jacobian, sirhan, assumes, jscript, advisers,
# ('Average loss at step ', 72000, ': ', 0.93889791774749753)
# ('Average loss at step ', 74000, ': ', 0.94238742354512217)
# ('Average loss at step ', 76000, ': ', 0.93366397413611413)
# ('Average loss at step ', 78000, ': ', 0.93796201571822169)
# ('Average loss at step ', 80000, ': ', 0.93230059292912482)
# Nearest to was: hassan, creating, breakthroughs, subjunctive, ballista, mackintosh, yusupov, htm,
# Nearest to who: timbres, populations, tsushima, enjoy, activision, trailers, ward, presley,
# Nearest to four: ensued, macedonia, courted, scantily, wysiwyg, lovelock, unambiguously, stamped,
# Nearest to history: lemming, pilgrims, libel, byrnes, frontal, comfortably, refugee, trait,
# Nearest to such: romanum, osamu, yearbook, vanderbilt, roundly, travolta, kashima, uranium,
# Nearest to this: ankh, bobby, dizzy, silicon, bidder, boitano, curly, nevado,
# Nearest to eight: whitehead, pythagorean, meteor, splitting, antagonistic, catiline, eradicate, montessori,
# Nearest to about: contexts, debilitating, protocol, creeping, inclusive, chant, middle, mand,
# Nearest to UNK: the, used, class, has, self, a, taken, any,
# Nearest to these: tropes, broz, designed, schottenheimer, archeological, surfacing, townes, czes,
# Nearest to years: tubas, televised, transliterated, adequacy, colitis, residue, stained, mathematically,
# Nearest to use: harbors, outburst, bendix, staking, declined, hexagonal, contested, leche,
# Nearest to the: of, used, a, term, to, as, class, working,
# Nearest to united: labouring, supposedly, agronomy, forgiving, dancing, reconstructionism, presidential, quimby,
# Nearest to that: also, as, used, to, by, the, french, a,
# Nearest to often: crystallization, lya, guiding, jacobian, sirhan, assumes, jscript, advisers,
# ('Average loss at step ', 82000, ': ', 0.93903686439990997)
# ('Average loss at step ', 84000, ': ', 0.93793949018418787)
# ('Average loss at step ', 86000, ': ', 0.94184009242057798)
# ('Average loss at step ', 88000, ': ', 0.94228580760955816)
# ('Average loss at step ', 90000, ': ', 0.93417631477117535)
# Nearest to was: hassan, creating, breakthroughs, subjunctive, ballista, mackintosh, yusupov, htm,
# Nearest to who: timbres, populations, tsushima, enjoy, activision, trailers, ward, presley,
# Nearest to four: ensued, macedonia, courted, scantily, wysiwyg, lovelock, unambiguously, stamped,
# Nearest to history: lemming, pilgrims, libel, byrnes, frontal, comfortably, refugee, trait,
# Nearest to such: romanum, osamu, yearbook, vanderbilt, roundly, travolta, kashima, uranium,
# Nearest to this: ankh, bobby, dizzy, silicon, bidder, boitano, curly, nevado,
# Nearest to eight: whitehead, pythagorean, meteor, splitting, antagonistic, catiline, eradicate, montessori,
# Nearest to about: contexts, debilitating, protocol, creeping, inclusive, chant, middle, mand,
# Nearest to UNK: the, used, has, class, to, self, a, any,
# Nearest to these: tropes, broz, designed, schottenheimer, archeological, surfacing, townes, czes,
# Nearest to years: tubas, televised, transliterated, adequacy, colitis, residue, stained, mathematically,
# Nearest to use: harbors, outburst, bendix, staking, declined, hexagonal, contested, leche,
# Nearest to the: to, of, used, a, term, as, class, society,
# Nearest to united: labouring, supposedly, agronomy, forgiving, dancing, reconstructionism, presidential, quimby,
# Nearest to that: also, to, as, by, used, the, french, has,
# Nearest to often: crystallization, lya, guiding, jacobian, sirhan, assumes, jscript, advisers,
# ('Average loss at step ', 92000, ': ', 0.93739539983868603)
# ('Average loss at step ', 94000, ': ', 0.9325857547521591)
# ('Average loss at step ', 96000, ': ', 0.9451288601756096)
# ('Average loss at step ', 98000, ': ', 0.93450532606244086)
# ('Average loss at step ', 100000, ': ', 0.93417967718839645)
# Nearest to was: hassan, creating, breakthroughs, subjunctive, ballista, mackintosh, yusupov, htm,
# Nearest to who: timbres, populations, tsushima, enjoy, activision, trailers, ward, presley,
# Nearest to four: ensued, macedonia, courted, scantily, wysiwyg, lovelock, unambiguously, stamped,
# Nearest to history: lemming, pilgrims, libel, byrnes, frontal, comfortably, refugee, trait,
# Nearest to such: romanum, osamu, yearbook, vanderbilt, roundly, travolta, kashima, uranium,
# Nearest to this: ankh, bobby, dizzy, silicon, bidder, boitano, curly, nevado,
# Nearest to eight: whitehead, pythagorean, meteor, splitting, antagonistic, catiline, eradicate, montessori,
# Nearest to about: contexts, debilitating, protocol, creeping, inclusive, chant, middle, mand,
# Nearest to UNK: used, has, class, the, self, to, term, a,
# Nearest to these: tropes, broz, designed, schottenheimer, archeological, surfacing, townes, czes,
# Nearest to years: tubas, televised, transliterated, adequacy, colitis, residue, stained, mathematically,
# Nearest to use: harbors, outburst, bendix, staking, declined, hexagonal, contested, leche,
# Nearest to the: used, of, a, term, revolution, as, to, class,
# Nearest to united: labouring, supposedly, agronomy, forgiving, dancing, reconstructionism, presidential, quimby,
# Nearest to that: also, as, to, by, used, the, french, a,
# Nearest to often: crystallization, lya, guiding, jacobian, sirhan, assumes, jscript, advisers,
